# %% [markdown]
# # HDDLGym Tutorial
# Welcome to a walkthrough of HDDLGym system. This notebook provides the guide from create and modifying HDDL domains to run and train RL policy for hierarchical planning problem in multi-agent settings.
#
# Table of Contents
# 1. [Modify HDDL files to adapt to the HDDLGym system](#1-Modify-HDDL-files-to-adapt-to-the-HDDLGym-system)
#
# 2. [Test HDDL domain and problem with random exploration](#2-Test-HDDL-domain-and-problem-files-with-random-exploration)
#
# 3. [Pretrain Problem Analysis](#3-Pretrain-Problem-Analysis)
#
# 4. [Design a RL policy](#4-Design-a-RL-policy)
#
# 5. [Train RL policy](#4-Train-RL-policy)
#
# 6. [Deploy RL policy](#5-Deploy-RL-policy)
#
# 7. [Extra - Overcooked Policy Visualization Tutorial](#Overcooked-Policy-Visualization-Tutorial)

# %% [markdown]
# # Install dependencies
# For majority of features of HDDLGym, we need general python packages such as gym, torch, tensorboard, etc.
#
# Additionally, for required packages to run demo such as Overcooked, please look at _requirements.txt_.
#
# On the other hand, you can use Docker to run the code. In this case, please make sure to adjust the command in _Dockerfile_ to match your purpose.
#
# [back to top](#HDDLGym-Tutorial)

# %%
# !pip install ipykernel
# !pip install gym
# !pip install gymnasium
# !pip install torch
# !pip install tensorboard
# !pip install pytorch torchvision
# Out:
# Requirement already satisfied: ipykernel in /home/nicole/anaconda3/lib/python3.13/site-packages (6.30.1)
# Requirement already satisfied: comm>=0.1.1 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (8.30.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil>=5.7 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: pyzmq>=25 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: stack-data in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/nicole/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: wcwidth in /home/nicole/anaconda3/lib/python3.13/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/nicole/anaconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nicole/anaconda3/lib/python3.13/site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/nicole/anaconda3/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/nicole/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/nicole/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing in /home/nicole/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: asttokens in /home/nicole/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /home/nicole/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: gym in /home/nicole/anaconda3/lib/python3.13/site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from gym) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from gym) (3.0.0)
# Requirement already satisfied: gym_notices>=0.0.4 in /home/nicole/anaconda3/lib/python3.13/site-packages (from gym) (0.1.0)
# Requirement already satisfied: gymnasium in /home/nicole/anaconda3/lib/python3.13/site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from gymnasium) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/nicole/anaconda3/lib/python3.13/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch in /home/nicole/anaconda3/lib/python3.13/site-packages (2.9.0)
# Requirement already satisfied: filelock in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from torch) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: tensorboard in /home/nicole/anaconda3/lib/python3.13/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=0.4 in /home/nicole/anaconda3/lib/python3.13/site-packages (from tensorboard) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /home/nicole/anaconda3/lib/python3.13/site-packages (from tensorboard) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/nicole/anaconda3/lib/python3.13/site-packages (from tensorboard) (3.8)
# Requirement already satisfied: numpy>=1.12.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from tensorboard) (2.1.3)
# Requirement already satisfied: packaging in /home/nicole/anaconda3/lib/python3.13/site-packages (from tensorboard) (24.2)
# Requirement already satisfied: pillow in /home/nicole/anaconda3/lib/python3.13/site-packages (from tensorboard) (11.1.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/nicole/anaconda3/lib/python3.13/site-packages (from tensorboard) (5.29.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from tensorboard) (72.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/nicole/anaconda3/lib/python3.13/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/nicole/anaconda3/lib/python3.13/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: typing-extensions~=4.12 in /home/nicole/anaconda3/lib/python3.13/site-packages (from grpcio>=1.48.2->tensorboard) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/nicole/anaconda3/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: setuptools>=40.8.0 in /home/nicole/miniconda3/lib/python3.10/site-packages (from triton==3.4.0->torch) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/nicole/miniconda3/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nicole/miniconda3/lib/python3.10/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: tensorboard in /home/nicole/miniconda3/lib/python3.10/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=0.4 in /home/nicole/miniconda3/lib/python3.10/site-packages (from tensorboard) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /home/nicole/miniconda3/lib/python3.10/site-packages (from tensorboard) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/nicole/miniconda3/lib/python3.10/site-packages (from tensorboard) (3.9)
# Requirement already satisfied: numpy>=1.12.0 in /home/nicole/miniconda3/lib/python3.10/site-packages (from tensorboard) (2.2.6)
# Requirement already satisfied: packaging in /home/nicole/miniconda3/lib/python3.10/site-packages (from tensorboard) (25.0)
# Requirement already satisfied: pillow in /home/nicole/miniconda3/lib/python3.10/site-packages (from tensorboard) (11.3.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/nicole/miniconda3/lib/python3.10/site-packages (from tensorboard) (6.32.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/nicole/miniconda3/lib/python3.10/site-packages (from tensorboard) (78.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/nicole/miniconda3/lib/python3.10/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/nicole/miniconda3/lib/python3.10/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: typing-extensions~=4.12 in /home/nicole/miniconda3/lib/python3.10/site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/nicole/miniconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Collecting pytorch
#   Downloading pytorch-1.0.2.tar.gz (689 bytes)
#   Preparing metadata (setup.py) ... done
# Collecting torchvision
#   Downloading torchvision-0.24.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy in /home/nicole/miniconda3/lib/python3.10/site-packages (from torchvision) (2.2.6)
# Collecting torch==2.9.0 (from torchvision)
#   Downloading torch-2.9.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (0.7.1)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch==2.9.0->torchvision)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch==2.9.0->torchvision)
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/nicole/miniconda3/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (1.13.1.3)
# Collecting triton==3.5.0 (from torch==2.9.0->torchvision)
#   Downloading triton-3.5.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/nicole/miniconda3/lib/python3.10/site-packages (from sympy>=1.13.3->torch==2.9.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nicole/miniconda3/lib/python3.10/site-packages (from jinja2->torch==2.9.0->torchvision) (3.0.3)
# Downloading torchvision-0.24.0-cp310-cp310-manylinux_2_28_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 72.6 MB/s eta 0:00:00
# Downloading torch-2.9.0-cp310-cp310-manylinux_2_28_x86_64.whl (899.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 64.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 97.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 75.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading triton-3.5.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 MB 98.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Building wheels for collected packages: pytorch
#   DEPRECATION: Building 'pytorch' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pytorch'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for pytorch (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "/tmp/pip-install-qzmi3ua6/pytorch_74516ca90e7c4fa4b832405ab1068467/setup.py", line 15, in <module>
#           raise Exception(message)
#       Exception: You tried to install "pytorch". The package named for PyTorch is "torch"
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (pytorch)

# %% [markdown]
# # 1 Modify HDDL files to adapt to the HDDLGym system
# \(with an example of Transport domain\)
# As discussed in the paper, several modications are required before applying HDDL domain and problem files to the HDDLGym system.
#
# - Identify agent:
#
#     Identify and explicitly define "agent" as a type or a supertype.
#
#     For example, in Transport domain, 'vehicle' can be classified as an 'agent'.
#
#     If the domain has no type that can be classified as an agent, simply include 'agent' in the types block.
#
# - Add agent to parameters of agent-related actions:
#
#     For _:action_ blocks that defined agent-related actions, please ensure to include 'agent' or agent's type in its parameters.
#
# - Add effects to tasks
#
#     Each _:task_ block are required to include _effects_.
#
# - Add none-action to the domain:
#
#     Please ensure there is a block of none-action in the domain file. If there is similar action (but different name), then replace it with the none-action. The none-action block should be:
#
#
#     (:action none
#
# >:parameters (?agent - agent)
#
# >:precondition ()
#
# >:effect ()
#     )
#
# ### Checking if HDDL domain files meet HDDLGym format requirements:
# Use the following code to check your the HDDL domain files
#
# [back to top](#HDDLGym-Tutorial)

# %%
# Some helper functions 
import re
import os
from HDDL_files.modify_hddl_domain_for_HDDLGym import remove_comments_from_hddl
def check_none_action_defined_correctly(file_path, with_none_name=True):
    '''
    check if in the HDDL file (file_path), the none action is defined correctly
    '''
    temp_file = file_path.split('.hddl')[0] + '_temp.hddl'
    remove_comments_from_hddl(file_path,temp_file)
    if with_none_name:
        # Define a regex pattern to match the 'none' action with strict conditions
        pattern = re.compile(
            r"\(:action\s+none\s*"  # Match the action definition
            r":parameters\s*\(\?\w+\s*-\s*agent\)\s*"  # Match any parameter name before "- agent"
            r":precondition\s*\(\)\s*"  # Match empty precondition
            r":effect\s*\(\)\s*"  # Match empty effect
            r"\)",  # Closing parenthesis
            re.MULTILINE
        )
    else:
        pattern = re.compile(
            r"\(:action\s+([^\s]+)\s*"  # Capture action name (group 1)
            r":parameters\s*\(\?\w+\s*-\s*agent\)\s*"  # Match any parameter name before "- agent"
            r":precondition\s*\(\)\s*"  # Match empty precondition
            r":effect\s*\(\)\s*"  # Match empty effect
            r"\)",  # Closing parenthesis
            re.MULTILINE
        )

    # Read the PDDL file
    with open(temp_file, "r") as file:
        content = file.read()
    # remove temp_file:
    if os.path.exists(temp_file):
        os.remove(temp_file)
    # Check if the pattern exists in the HDDL file
    if with_none_name:
        if pattern.search(content):
            # print("The action `none` is correctly defined in the HDDL file.")
            return True
        else:
            # print("The action `none` is missing or incorrectly formatted.")
            return False
    else:
        matches = pattern.findall(content)
        if matches:
            ans_str = "Found similar action(s) to none-action but with different name:\n"
            for action in matches:
                ans_str += f" {action}\n"
                if len(matches) == 1:
                    ans_str += f"---> Suggest change its name to none: '{action}' ==> 'none'"
            if len(matches) > 1:
                ans_str += "---> Suggest combine these similar actions into one action and name it 'none'."
            return ans_str
        else:
            return "No similar action to none-action"
print("Helper functions loaded")
# Out:
# Helper functions loaded

# %%
print("\n--- Checking HDDL domain file format ---")
from HDDL_files.modify_hddl_domain_for_HDDLGym import check_hddl_format, parse_types, is_agent_in_hierarchy, get_all_subtypes
from HDDL_files.modify_hddl_domain_for_HDDLGym import remove_comments_from_hddl
import os
from pathlib import Path
from HDDL_files.problems_dir import PROBLEMS # a dictionary of some domain and problem files
script_dir = Path(os.getcwd())
print("Current directory:", script_dir)
def find_actions_without_agent(file_path, agent_type='agent'):
    """Find actions that do not use 'agent' or its subtypes."""
    type_hierarchy = parse_types(file_path, debug=False)
    agent_related_types = {agent_type}.union(get_all_subtypes(type_hierarchy, agent_type))
    print("Agent-related types:", agent_related_types)

    with open(file_path, 'r') as file:
        content = file.read()

    # Extract all :action blocks
    action_pattern = re.compile(r'\(:action\s+([\w-]+).*?:parameters\s*\((.*?)\)', re.DOTALL)
    actions_without_agent = []

    for match in action_pattern.finditer(content):
        action_name = match.group(1)
        parameters = match.group(2)

        # Extract parameter types
        parameter_types = re.findall(r'\?[\w-]+\s+-\s+([\w-]+)', parameters)
        if not any(ptype in agent_related_types for ptype in parameter_types):
            actions_without_agent.append(action_name)

    return actions_without_agent

# TO DO: Modify the domain_file_dir to check if your HDDL domain file meets requirements
# domain_file = str(script_dir / "HDDL_files/Custom_environments/SearchAndRescue/SAR_domain.hddl")
# problem_file = str(script_dir / "HDDL_files/Custom_environments/SearchAndRescue/SAR_problem.hddl")
# End To Do


# TO DO: replace the domain_file and problem_file below with your files    
# domain_file = "HDDL_files/Overcooked_specialization/overcooked_short_domain.hddl"
# problem_file = "HDDL_files/Overcooked_specialization/overcooked_short_prob2.hddl"
print("Here is a list of problems: \n",'\n'.join(list(PROBLEMS.keys())))
problem_name_is_valid = False
while not problem_name_is_valid:
    problem_name = input("Enter the problem name (key) from PROBLEMS dictionary (e.g., 'overcooked_2agents_collab'): ")
    if problem_name in PROBLEMS.keys():
        domain_file, problem_file = PROBLEMS[problem_name]
        problem_name_is_valid = True
    else:
        print(f"Invalid problem name '{problem_name}'. Please try again. Use one of these: {list(PROBLEMS.keys())}")
domain_file = str(script_dir / domain_file)
problem_file = str(script_dir / problem_file)

print(f"Using domain file: {domain_file}")
print(f"Using problem file: {problem_file}")
# End TO DO

# Assign directory for the valid domain file:

# Remove all comments before checking the format:
domain_file_no_comments = domain_file.split('.hddl')[0] + '_no_comments.hddl'
problem_file_no_comments = problem_file.split('.hddl')[0] + '_no_comments.hddl'
remove_comments_from_hddl(domain_file, domain_file_no_comments)
remove_comments_from_hddl(problem_file, problem_file_no_comments)

# Check if the domain file has 'agent' in the type:
print("*** Checking if the domain file has 'agent' in the type block ***")
type_hierarchy = parse_types(domain_file_no_comments, debug=False)
if type_hierarchy:
    is_agent_in_hierarchy(type_hierarchy)

# Agent-related actions and environment actions:
print("\n***Checking if agent is in parameters of actions ***")
no_agent_actions = find_actions_without_agent(domain_file_no_comments)
print("No agent actions: ", no_agent_actions)
if len(no_agent_actions):
    print("---> Suggest adding '?agent - agent' in the parameter if any action above is not an environment action!")

# Check None-action:
print("\n*** Checking none-action ***")
if check_none_action_defined_correctly(domain_file_no_comments, with_none_name = True):
    print("The none action is correctly defined.")
else:
    print("No none-action is defined as required.")
    error = check_none_action_defined_correctly(domain_file_no_comments, with_none_name=False)
    print(error)

# Check if the domain file has correct number of parentheses, actions, tasks, methods with correct format:
print("\n*** Checking general format of action, task, and method blocks ***")
check_hddl_format(domain_file_no_comments)
print("End of checking the domain file format.")
# Out:
# --- Checking HDDL domain file format ---
# Current directory: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo
# Here is a list of problems:
#  overcooked_2agents_collab
# overcooked_3agents_collab
# transport_1agent_collab
# transport_1agent_no_collab
# transport_2agents_collab
# transport_2agents_no_collab
# transport_2agents_heterogeneous
# transport_2agents_heterogeneous_without_collabmethod
# transport_3agents_collab
# transport_3agents_no_collab
# transport_2agents_heterogeneous_with_noop
# rover_1agent
# rover_2agents
# rover_3agents
# rover_4agents
# satellite_1obs_1sat_1mod
# satellite_2obs_2sat_1mod
# satellite_3obs_3sat_1mod
# satellite_4obs_4sat_4mod
# barman_bdi_2agents_1drink
# barman_bdi_2agents_2drinks
# barman_bdi_2agents_3drinks
# depots_1agent
# zenotravel_1agent
# zenotravel_2agents
# factories_simple_1agent
# minecraft_player_1agent_003
# search_and_rescue_1agent
# taxi_2agents
# Enter the problem name (key) from PROBLEMS dictionary (e.g., 'overcooked_2agents_collab'):  overcooked_2agents_collab
# Using domain file: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl
# Using problem file: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl
# *** Checking if the domain file has 'agent' in the type block ***
#
# ***Checking if agent is in parameters of actions ***
# Agent-related types: {'agent'}
# No agent actions:  ['cooking', 'a-complete-cooking']
# ---> Suggest adding '?agent - agent' in the parameter if any action above is not an environment action!
#
# *** Checking none-action ***
# The none action is correctly defined.
#
# *** Checking general format of action, task, and method blocks ***
# HDDL file format is correct.
# End of checking the domain file format.

# %% [markdown]
# # 2 Test HDDL domain and problem files with random exploration
#
# To test if the HDDLGym Planner working with the HDDL domain and problem files, we run the environment with random exploration
#
# [back to top](#HDDLGym-Tutorial)

# %%
from learning_methods import evaluate_policy
from hddl_env import HDDLEnv
from HDDL_files.modify_hddl_domain_for_HDDLGym import remove_comments_from_hddl
from learning_methods import PPO_discrete
import torch
from HDDL_files.problems_dir import PROBLEMS # a dictionary of some domain and problem files

# TO DO: replace the domain_file and problem_file below with your files    
# domain_file = "HDDL_files/Overcooked_specialization/overcooked_short_domain.hddl"
# problem_file = "HDDL_files/Overcooked_specialization/overcooked_short_prob2.hddl"
problem_name_is_valid = False
while not problem_name_is_valid:
    problem_name = input("Enter the problem name (key) from PROBLEMS dictionary (e.g., 'overcooked_2agents_collab'): ")
    if problem_name in PROBLEMS.keys():
        domain_file, problem_file = PROBLEMS[problem_name]
        problem_name_is_valid = True
    else:
        print(f"Invalid problem name '{problem_name}'. Please try again. Use one of these: {list(PROBLEMS.keys())}")
domain_file = str(script_dir / domain_file)
problem_file = str(script_dir / problem_file)

print(f"Using domain file: {domain_file}")
print(f"Using problem file: {problem_file}")
# End TO DO

class Parameters():
    # Mimicking the arguments of parse_arguments for main_train.py
    def __init__(self, domain, problem):
        self.dvc = 'cpu' # running device: cuda or cpu
        self.domain = domain # directory to domain file
        self.problem = problem # directory to problem file
        self.state_dim = None # state dimension
        self.action_dim = None # action dimension
        self.use_central_planner = False
        self.planner_time_limit = 5
        self.write = False
        self.Loadmodel = False
        self.debug = False
        # related to training:
        self.net_width = 64
        self.lr = 1e-4
        self.T_horizon = 2048
        self.seed = 502
        self.activation = 'tanh'
        self.gamma = 0.9
        self.max_e_steps = 120
        


domain_file_no_comments = domain_file.split('.hddl')[0] + '_no_comments.hddl'
problem_file_no_comments = problem_file.split('.hddl')[0] + '_no_comments.hddl'
remove_comments_from_hddl(domain_file, domain_file_no_comments)
remove_comments_from_hddl(problem_file, problem_file_no_comments)
opt = Parameters(domain=domain_file_no_comments, problem=problem_file_no_comments)


class RandomPolicy():
    def __init__(self, state_dim, action_dim):
        self.state_dim = state_dim
        self.action_dim = action_dim

    def select_action(self, s, deterministic=False, value=False):
        # regardless deterministic or not, it is still a random process
        probabilities = torch.rand(self.action_dim)  # Generate random values
        probabilities /= probabilities.sum()  # Normalize to sum to 1
        if value:
            return probabilities
        else:
            return argmax


###
env = HDDLEnv(opt.domain, opt.problem, max_step=opt.max_e_steps)
opt.state_dim = env.observation_space.n
opt.action_dim = env.action_space.n
# Two way to do random exploration:
# 1. Use PPO_discrete when it is just randomly initiated, when the weights are not trained.
# policy = PPO_discrete(**vars(opt)).to(opt.dvc)
# 2. to create a RandomPolicy as follow:
policy = RandomPolicy(opt.state_dim, opt.action_dim) # random policy defined above
score = evaluate_policy(env, policy, turns = 1, opt=opt, debug=False)
print('SCORE: ', score)
# Out:
# Enter the problem name (key) from PROBLEMS dictionary (e.g., 'overcooked_2agents_collab'):  taxi_2agents
# Using domain file: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Taxi/domain.hddl
# Using problem file: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Taxi/problem1.hddl
# SCORE:  -19

# %% [markdown]
# # 3 Pretrain Problem Analysis
#
# Before designing a RL policy and train it, it is important to run pretrain analysis to understand the domain and problems that you are interested in studying. This Pretrain Analysis provides information about:
#
#  1. Complexity of the environment (number of lifted/grounded operators, number of grounded predicates, number of grounded dynamic predicates)
#
#  2. Difficulty of the environment (success rate, plan time, and plan steps of hierarchical planning with a random policy)
#
# The first complexity of the environment can be helpful in designing the observation and action space, giving users some ideas about dimensions of the inputs and outputs of the RL models. For example, if the number of grounded predicates is too large, users may want to consider using grounded dynamic predicates to reduce the size of the observation space.
#
# To run the pretrain analysis for just one problem, following these steps:
#
# 1. Run the following command:
#
#    `python pretrain_analysis.py <problem_name>`
#
#    Where problem_name is the name of the problem. Users can check the file HDDL_files/problems_dir.py to see all the problem names and compatible directories of domain and problem files.
#
# 2. The results are saved in the json files *pretrain_analysis_complexity_result.json* and *pretrain_analysis_difficulty_result.json*.
#
#
# To run pretrain analysis for all the problem in the HDDL_files/problems_dir.py, following these steps:
#
# 1. Check and/or modify the file *HDDL_files/problems_dir.py*. This file contains a dictionary PROBLEMS which includes all the directories to the domains and problems that need to run pretrain analysis. If you only want to run some specific domains and problesm, you can comment out all other problems.
#
# 2. Run the python file *pretrain_analysis.py* with the command in terminal:
#
#    `python pretrain_analysis.py ALL`
#
#     The *ALL* value for *problem_name* will help bypass the error of not having a proper *problem_name*, as well as trigger running analysis for all problems specified in *HDDL_files/problem_dir.py*.
#
# 4. The results are saved in the json files *pretrain_analysis_complexity_result.json* and *pretrain_analysis_difficulty_result.json*.
#
#
# Examples of pretrain analysis results are in the paper, Table 1 and Table 3.

# %%
# !python3 pretrain_analysis.py --problem-name ALL
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using default or manual directions for domain and problem files:
# - DOMAIN: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl
# - PROBLEM: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl
# Namespace(dvc=device(type='cpu'), problem_name='ALL', domain='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl', problem='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl', write=False, run_training=True, use_central_planner=False, debug=False, planner_time_limit=5, seed=1, T_horizon=2048, max_e_steps=50, monitor_training=False, Loadmodel=False, Model=None, Max_train_steps=100000000.0, save_interval=1000.0, eval_interval=1000.0, gamma=0.99, lambd=0.95, clip_rate=0.2, K_epochs=10, net_width=64, lr=0.0001, l2_reg=0, batch_size=2048, entropy_coef=0.01, entropy_coef_decay=0.99, adv_normalization=False, exploration_decay=0.999, activation='tanh', convergence_threshold=0.001)
# Using default or manual directions for domain and problem files:
# - DOMAIN: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl
# - PROBLEM: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl
# Namespace(dvc=device(type='cpu'), problem_name='ALL', domain='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl', problem='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl', write=False, run_training=True, use_central_planner=False, debug=False, planner_time_limit=5, seed=1, T_horizon=2048, max_e_steps=50, monitor_training=False, Loadmodel=False, Model=None, Max_train_steps=100000000.0, save_interval=1000.0, eval_interval=1000.0, gamma=0.99, lambd=0.95, clip_rate=0.2, K_epochs=10, net_width=64, lr=0.0001, l2_reg=0, batch_size=2048, entropy_coef=0.01, entropy_coef_decay=0.99, adv_normalization=False, exploration_decay=0.999, activation='tanh', convergence_threshold=0.001)
# Using default or manual directions for domain and problem files:
# - DOMAIN: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl
# - PROBLEM: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl
# Namespace(dvc=device(type='cpu'), problem_name='ALL', domain='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl', problem='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl', write=False, run_training=True, use_central_planner=False, debug=False, planner_time_limit=5, seed=1, T_horizon=2048, max_e_steps=50, monitor_training=False, Loadmodel=False, Model=None, Max_train_steps=100000000.0, save_interval=1000.0, eval_interval=1000.0, gamma=0.99, lambd=0.95, clip_rate=0.2, K_epochs=10, net_width=64, lr=0.0001, l2_reg=0, batch_size=2048, entropy_coef=0.01, entropy_coef_decay=0.99, adv_normalization=False, exploration_decay=0.999, activation='tanh', convergence_threshold=0.001)
# len of lifted predicate list: 7
# len of lifted dynamic predicate list: 3
# len of types list: 17
# len of objects list: 18
# len of type object dict: 17
# len of supertype type dict: 6
# len of grounded predicate list: 937158
# len of grounded dynamic predicate list: 90
# len of lifted tasks list: 6
# len of grounded tasks list: 1470
# len of lifted methods list: 7
# len of grounded methods list: 23336
# len of lifted actions list: 5
# len of grounded actions list: 175791
# len of grounded operators list: 200597
# len of lifted operators list: 18
# len of lifted environment actions list: 2
# len of grounded environment actions list: 37
# len of initial state: 51
# Traceback (most recent call last):
#   File "/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/pretrain_analysis.py", line 67, in <module>
#     data = get_env_complexity(opt)
#   File "/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/pretrain_analysis.py", line 21, in get_env_complexity
#     if debug: print(f"len of {key}: {len(env.env_dictionary[key])}")
#                                      ~~~^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: object of type 'HTN' has no len()

# %% [markdown]
# # 4 Design a RL policy
#
# Designing a RL policy is a feature that the HDDLGym would like to support. The current version of HDDLGym offer PPO_discrete policy. Its input (observation) is a one-hot coded array of dynamic grounded predicates, lifted operators and objects of all agents' previous action hierarchies.
#
# Navigating to the file **learning_methods.py**, users can modify contents of functions in the file to alternate the observation and action space, design of RL models, training methods, evaluating methods, ect., as long as the function names remain the same.
#
# Following is some simple examples of modifying functions in learning_methods.py to change different components of the design of RL policy.
#
# **RL model**
#
# To change the RL model, make sure the class of new model, please ensure to modify the following function accordingly:
# - For just deploying the policy (no training): \_\_init__, select_action
# - For both deploying and training: \_\_init__, select_action, to, train, put_data, save, and load
#
# [back to top](#HDDLGym-Tutorial)

# %%
class RandomPolicy():
    '''Notes: 
    This Random Policy is just for deploying the HDDLGym Planner with random exploration
    Therefore, only implement __init__ and select_action method.
    Other RL policies for require training like PPO_discrete should also implement other methods with similar features as functions in PPO_discrete 
    (such as train, put_data, save, and load)
    '''
    def __init__(self, state_dim, action_dim):
        self.state_dim = state_dim
        self.action_dim = action_dim

    def select_action(self, s, deterministic=False, value=False):
        '''select action
        input:
        - s: an array representing the observation, or input for the policy
        - deterministic: boolen, whether to choose action with the max value or
                        to randomly choose it with weights are value of the policy
        - value: boolean, whether to return the value of policy (probability list)
        output:
        - either probabilities or index of action with max probability (or value), depending on the value flag.
        '''
        # regardless deterministic or not, it is still a random process
        probabilities = torch.rand(self.action_dim)  # Generate random values
        probabilities /= probabilities.sum()  # Normalize to sum to 1
        if value:
            return probabilities
        else:
            max_index = probabilities.index(max(probabilities))
            return max_index

# %% [markdown]
# **Observation-Action Spaces**
#
# To change the observation and action spaces, modifying the contents of functions:
# - *get_observation_space*: specify what elements from the env_dictionary are in the observation. Here are some examples:
#   - \[default\] grounded dynamic predicates + lifted operators + related objects
#   - grounded dynamic predicates + lifted operators
#   - grounded predicates
# - *get_action_space*: specify what elements of the env_dictionary are in the action. Some examples are:
#   - \[default\] lifted operators + related objects
#   - lifted operators
#   - lifted method + lifted task + grounded action
# - *get_prob_from_prob_list*: get the probability of a grounded operator from the output of the policy (probability array)
#   - Depend on how the action space is designed, the probability of a grounded operator (g_oper) is calculated using the probabilities of elements that are relevant to the grounded operator (g_oper). For example:
#     - \[default\] logprob of g_oper =  mean(logprob of lifted operator of g_oper + logprob of objects in g_oper))
#     - if action space is grounded operators, then prob of g_oper can be directly get from the corresponding value in the probability array.
#
# - *get_observation_one_hot_vector*: generate observation array for the policy from the information of the current state (including current grounded predicates in the env, previous action or action hierarchy of agents). This function is modified according to how the observation space is defined.
#
# *Belows are default functions in learning_methods.py that are relevant to desgining observation-action spaces.*

# %%
# Change observation and action space:
def get_observation_space(env_dictionary):
    '''
    This function return the size of observation space (or state space), which is also the output size of the RL policy
    input:
    - env_dictionary: environment dictionary, result of parsing the HDDL domain and problem file
    output:
    - gym.spaces.Discrete(n), with n is the len of observation
    Note: 
    - in this approach, the observation space involves grounded dynamic predicate list, lifted action, and object list
    '''
    observation_space = gym.spaces.Discrete(n=len(env_dictionary['grounded dynamic predicate list'])+\
          len(env_dictionary['lifted operators list'])+len(env_dictionary['objects list']))

    # Replace the above line of code by the below line, if just don't want to have objects list in observation:
    # observation_space = gym.spaces.Discrete(n=len(env_dictionary['grounded dynamic predicate list'])+\
          # len(env_dictionary['lifted operators list']))
    return observation_space

def get_action_space(env_dictionary):
    '''
    This function return the size of action space, which is also the output size of the RL policy
    input:
    - env_dictionary: environment dictionary, result of parsing the HDDL domain and problem file
    output:
    - gym.spaces.Discrete(n), with n is the len of action
    Note: 
    - in this approach, the action space involves lifted action and object list
    '''
    action_space = gym.spaces.Discrete(n=len(env_dictionary['lifted operators list'])+len(env_dictionary['objects list']))
    # Use the below line of code instead if don't want include objects in action space
    # action_space = gym.spaces.Discrete(n=len(env_dictionary['lifted operators list']))
    return action_space

def get_prob_from_prob_list(operator_str, prob_list, env_dictionary,device='cpu'):
  '''This function provide probability value (prob) for the operator_str according to probabilities in the prob_list
  inputs:
  - operator_str: a string of operator_name + objects
  - prob_list: a tensor, listing prob of lifted operators and objects
  - env_dictionary: dictionary of environment's elements
  outpus:
  - prob: a float number of the probability of the operator_str
  '''
  oper_name, oper_obj = extract_object_list(operator_str)
  oper_lifted_id = None
  for lifted_ind, lifted_oper in enumerate(env_dictionary['lifted operators list']):
    if lifted_oper.name == oper_name:
      oper_lifted_id = lifted_ind
  assert oper_lifted_id != None, "Could not find lifted operators of oper {}".format(operator_str)
  indices_list = [oper_lifted_id]
  for obj in oper_obj:
    indices_list.append(env_dictionary['objects list'].index(obj) + len(env_dictionary['lifted operators list']))

  relevant_prob_tensor = prob_list[indices_list]
  prob = torch.exp(torch.div(torch.sum(torch.log(relevant_prob_tensor)),len(indices_list)+1e-20))
  return prob


def get_observation_one_hot_vector(current_state, all_operators, env_dictionary, device=False):
    '''Get observation from current state and operators from action hierarchies
    inputs:
    - current_state: list of predicate
    - all_operators: list of all operators
    - env_dictionary: environment dictionary
    - device: the device (CPU/GPU) to place the tensors on
    output:
    - observation: PyTorch tensor on the specified device
    '''
    if not device:
      device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    state_num = enumerate_list(current_state, env_dictionary['grounded dynamic predicate list'])
    state_num_tensor = torch.tensor(state_num, device=device, dtype=torch.float32)
    lifted_operators_id, objects_id = convert_grounded_to_lifted_index(
        all_operators, env_dictionary['lifted operators list'], env_dictionary['objects list']
    )

    lifted_operator_matrix = enumerate_index_to_binary_matrix(
        lifted_operators_id, array_len=len(env_dictionary['lifted operators list']), device=device
    )

    object_matrix = enumerate_index_to_binary_matrix(
        objects_id, array_len=len(env_dictionary['objects list']), device=device
    )

    observation = torch.cat([state_num_tensor, lifted_operator_matrix, object_matrix])

    return observation

# %%
# !python main_train.py --help
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# usage: main_train.py [-h] [--dvc DVC] --problem-name PROBLEM_NAME
#                      [--domain DOMAIN] [--problem PROBLEM]
#                      [--write WRITE] [--run-training RUN_TRAINING]
#                      [--use-central-planner USE_CENTRAL_PLANNER]
#                      [--debug DEBUG]
#                      [--planner-time-limit PLANNER_TIME_LIMIT]
#                      [--seed SEED] [--T-horizon T_HORIZON]
#                      [--max-e-steps MAX_E_STEPS]
#                      [--monitor-training MONITOR_TRAINING]
#                      [--Loadmodel LOADMODEL] [--Model MODEL]
#                      [--Max-train-steps MAX_TRAIN_STEPS]
#                      [--save-interval SAVE_INTERVAL]
#                      [--eval-interval EVAL_INTERVAL] [--gamma GAMMA]
#                      [--lambd LAMBD] [--clip-rate CLIP_RATE]
#                      [--K-epochs K_EPOCHS] [--net-width NET_WIDTH]
#                      [--lr LR] [--l2-reg L2_REG]
#                      [--batch-size BATCH_SIZE]
#                      [--entropy-coef ENTROPY_COEF]
#                      [--entropy-coef-decay ENTROPY_COEF_DECAY]
#                      [--adv-normalization ADV_NORMALIZATION]
#                      [--exploration-decay EXPLORATION_DECAY]
#                      [--activation ACTIVATION]
#                      [--convergence-threshold CONVERGENCE_THRESHOLD]
#
# options:
#   -h, --help            show this help message and exit
#   --dvc DVC             running device: cuda or cpu
#   --problem-name PROBLEM_NAME
#                         Provide the name of the problem, should be in
#                         one of:
#                         dict_keys(['overcooked_2agents_collab',
#                         'overcooked_3agents_collab',
#                         'transport_1agent_collab',
#                         'transport_1agent_no_collab',
#                         'transport_2agents_collab',
#                         'transport_2agents_no_collab',
#                         'transport_2agents_heterogeneous', 'transport_
#                         2agents_heterogeneous_without_collabmethod',
#                         'transport_3agents_collab',
#                         'transport_3agents_no_collab',
#                         'transport_2agents_heterogeneous_with_noop',
#                         'rover_1agent', 'rover_2agents',
#                         'rover_3agents', 'rover_4agents',
#                         'satellite_1obs_1sat_1mod',
#                         'satellite_2obs_2sat_1mod',
#                         'satellite_3obs_3sat_1mod',
#                         'satellite_4obs_4sat_4mod',
#                         'barman_bdi_2agents_1drink',
#                         'barman_bdi_2agents_2drinks',
#                         'barman_bdi_2agents_3drinks', 'depots_1agent',
#                         'zenotravel_1agent', 'zenotravel_2agents',
#                         'factories_simple_1agent',
#                         'minecraft_player_1agent_003',
#                         'search_and_rescue_1agent', 'taxi_2agents'])
#   --domain DOMAIN       Which domain HDDL file to load?
#   --problem PROBLEM     Which problem HDDL file to load?
#   --write WRITE         Use SummaryWriter to record the training
#   --run-training RUN_TRAINING
#                         Train or evaluate the model, True for
#                         training, False for evaluation
#   --use-central-planner USE_CENTRAL_PLANNER
#                         Whether to run centralized planner for multi-
#                         agent planning, default to False
#   --debug DEBUG         Debug mode or Not
#   --planner-time-limit PLANNER_TIME_LIMIT
#                         The time limit (in seconds) for running the
#                         planner for each agent at each step
#   --seed SEED           random seed
#   --T-horizon T_HORIZON
#                         lenth of long trajectory
#   --max-e-steps MAX_E_STEPS
#                         Max number of steps in each episode
#   --monitor-training MONITOR_TRAINING
#                         Monitor training or not
#   --Loadmodel LOADMODEL
#                         Load pretrained model or Not
#   --Model MODEL         which model to load
#   --Max-train-steps MAX_TRAIN_STEPS
#                         Max training steps
#   --save-interval SAVE_INTERVAL
#                         Model saving interval, in steps.
#   --eval-interval EVAL_INTERVAL
#                         Model evaluating interval, in steps.
#   --gamma GAMMA         Discounted Factor
#   --lambd LAMBD         GAE Factor
#   --clip-rate CLIP_RATE
#                         Clip rate
#   --K-epochs K_EPOCHS   update times - number of epochs of training
#   --net-width NET_WIDTH
#                         Hidden net width
#   --lr LR               Learning rate
#   --l2-reg L2_REG       L2 regulization coefficient for Critic (PPO)
#   --batch-size BATCH_SIZE
#                         lenth of sliced trajectory
#   --entropy-coef ENTROPY_COEF
#                         Entropy coefficient of Actor
#   --entropy-coef-decay ENTROPY_COEF_DECAY
#                         Decay rate of entropy_coef
#   --adv-normalization ADV_NORMALIZATION
#                         Advantage normalization
#   --exploration-decay EXPLORATION_DECAY
#                         decay rate of exploration rate
#   --activation ACTIVATION
#                         activation function for learning model
#   --convergence-threshold CONVERGENCE_THRESHOLD
#                         Convergence threshold for training

# %% [markdown]
# # 5 Train RL policy
#
# For the default policy, we offer PPO_discrete, which is defined in **learning_methods.py**. To train the policy, first, make sure that the directories of domain and problem files are saved in the **HDDL_files/problems_dir.py**. Then, simply call **main_train.py**:
#
#     python main_train.py --problem-name <PROBLEM-NAME>
#
# There are parameters that users can either call with the command or modify in the file **main_train.py**. The common parameters are _domain_, _problem_ (file directions), and _dvc_ (training device option):
#
#     python main_train.py --domain <path/to/domain/file> --problem <path/to/problem/file> --dvc cpu
#
#
# ### Train custom RL policy:
#
# The file **main_train.py** in the codebase in used to train the default policy, PPO_discrete. However, if you design different RL methods, such as using different action spaces (lifted operation only) and/or observation space (use grounded predicates instead of dynamic grounded predicates), please ensure the observation and action space are modified in **learning_methods.py**, and the step of enumerating state and action in **main_train.py** are adjusted accordingly.
#
#
# [back to top](#HDDLGym-Tutorial)

# %%
# Call the default main_train.py:
# !python3 main_train.py
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using default or manual directions for domain and problem files:
# - DOMAIN: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl
# - PROBLEM: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl
# Namespace(dvc=device(type='cpu'), problem_name='default', domain='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl', problem='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl', write=False, run_training=True, use_central_planner=False, debug=False, planner_time_limit=5, seed=1, T_horizon=2048, max_e_steps=50, monitor_training=False, Loadmodel=False, Model=None, Max_train_steps=100000000.0, save_interval=1000.0, eval_interval=1000.0, gamma=0.99, lambd=0.95, clip_rate=0.2, K_epochs=10, net_width=64, lr=0.0001, l2_reg=0, batch_size=2048, entropy_coef=0.01, entropy_coef_decay=0.99, adv_normalization=False, exploration_decay=0.999, activation='tanh', convergence_threshold=0.001)
# Using default or manual directions for domain and problem files:
# - DOMAIN: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl
# - PROBLEM: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl
# Namespace(dvc=device(type='cpu'), problem_name='default', domain='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl', problem='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl', write=False, run_training=True, use_central_planner=False, debug=False, planner_time_limit=5, seed=1, T_horizon=2048, max_e_steps=50, monitor_training=False, Loadmodel=False, Model=None, Max_train_steps=100000000.0, save_interval=1000.0, eval_interval=1000.0, gamma=0.99, lambd=0.95, clip_rate=0.2, K_epochs=10, net_width=64, lr=0.0001, l2_reg=0, batch_size=2048, entropy_coef=0.01, entropy_coef_decay=0.99, adv_normalization=False, exploration_decay=0.999, activation='tanh', convergence_threshold=0.001)
# Using default or manual directions for domain and problem files:
# - DOMAIN: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_domain.hddl
# - PROBLEM: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing/Public_repo/HDDL_files/Custom_environments/Overcooked_specialization/overcooked_short_prob2.hddl
# opt.state_dim: 126
# opt.action_dim: 36
# Random Seed: 1
# Env: default   state_dim: 126   action_dim: 36    Random Seed: 1   max_e_steps: 50
#
#
# Successful episode count: 0 / 0 episodes

# %% [markdown]
# # 5 Deploy RL policy
# The section guides you through training a PPO model, running a rollout, and visualizing the results using a local server.
# - Run the trained model and record the plan
# - Visualize the hierarchical plan
#
# [back to top](#HDDLGym-Tutorial)

# %%
# Step 1: Train the Model
# This will generate model files like ppo_actor1000.pth and ppo_critic1000.pth in the 'model/' directory
# !python3 main_train.py
# Out:
# Namespace(K_epochs=10, Loadmodel=False, Max_train_steps=50000000.0, Model=2, T_horizon=2048, activation='tanh', adv_normalization=False, batch_size=64, clip_rate=0.2, debug=False, domain='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/HDDL_files/Overcooked_specialization/overcooked_short_domain.hddl', dvc=device(type='cpu'), entropy_coef=0.01, entropy_coef_decay=0.99, epsilon=1.0, eval_interval=1000.0, gamma=0.99, l2_reg=0, lambd=0.95, lr=0.0001, max_episode=50, max_step=25, net_width=64, planner_time_limit=5, problem='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/HDDL_files/Overcooked_specialization/overcooked_short_prob2.hddl', render=False, save_interval=1000.0, seed=209, use_central_planner=False, write=False)
# Namespace(K_epochs=10, Loadmodel=False, Max_train_steps=50000000.0, Model=2, T_horizon=2048, activation='tanh', adv_normalization=False, batch_size=64, clip_rate=0.2, debug=False, domain='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/HDDL_files/Overcooked_specialization/overcooked_short_domain.hddl', dvc=device(type='cpu'), entropy_coef=0.01, entropy_coef_decay=0.99, epsilon=1.0, eval_interval=1000.0, gamma=0.99, l2_reg=0, lambd=0.95, lr=0.0001, max_episode=50, max_step=25, net_width=64, planner_time_limit=5, problem='/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/HDDL_files/Overcooked_specialization/overcooked_short_prob2.hddl', render=False, save_interval=1000.0, seed=209, use_central_planner=False, write=False)
# /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/HDDL_files/Overcooked_specialization/overcooked_short_prob2.hddl
# opt.state_dim: 126
# opt.action_dim: 36
# Random Seed: 209
# Env: /home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/HDDL_files/Overcooked_specialization/overcooked_short_prob2.hddl   state_dim: 126   action_dim: 36    Random Seed: 209   max_e_steps: 25
#
#
#
#
# *** Episode 0 ***
# -- total train steps: 0
# Average step of successfull episodes: 0
# number of successful ep 0
#
#
# *** Episode 10 ***
# -- total train steps: 153
# Average step of successfull episodes: 16.3
# number of successful ep 10
#
#
# *** Episode 20 ***
# -- total train steps: 304
# Average step of successfull episodes: 16.2
# number of successful ep 20
# ^C
# Traceback (most recent call last):
#   File "main_train.py", line 313, in <module>
#     main_train(opt, debug=opt.debug)
#   File "main_train.py", line 139, in main_train
#     ag.decentralize_planner_agent(env, belief_other_agents = belief_other_agents,agent_policy = policy,\
#   File "/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/agent_class.py", line 123, in decentralize_planner_agent
#     list_agents = centralized_planner(world, main_agent_index = 0,all_agents = list_agents, all_policies = policy_list, debug=debug,\
#   File "/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/central_planner.py", line 88, in centralized_planner
#     valid_op_list, empty_by_others = generate_valid_operators(world, agent, print_empty_by_others=True)
#   File "/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/central_planner_utils.py", line 353, in generate_valid_operators
#     valid_op_list, empty_by_others = choose_subtask_policy(world.env_dictionary, world.current_state, method_str=agent.task_method_hierarchy[-1], agent=agent, subtask_policy = agent.agent_policy,\
#   File "/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/central_planner_utils.py", line 242, in choose_subtask_policy
#     _m_list = choose_method_policy(env_dictionary, state, sub, agent, method_policy=None, print_valid_list=True, debug=False)
#   File "/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/central_planner_utils.py", line 103, in choose_method_policy
#     if lifted_methods_list[i].precondition.check_precondition(state, var_obj_dict, debug=debug) and grounded_methods_list[i][j] not in agent.infeasible_task_method:
#   File "/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/hddl_utils.py", line 1266, in check_precondition
#     return self.grounded_precondition_literal.check_literal(state,debug=debug)
#   File "/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/hddl_utils.py", line 1345, in check_literal
#     if not element.check_literal(state, debug=debug):
#   File "/home/nicole/MIT Dropbox/Ngoc La/PhD/Projects/HDDLGym_developing_rebuttal/HDDLGym_dev/hddl_utils.py", line 1367, in check_literal
#     if self.literal_str not in state and debug:
# KeyboardInterrupt

# %% [markdown]
# ## 5.1: Run the HDDL Model
# Specify the exact model you want to use for the rollout by setting `opt.model`.
# For example, to use `ppo_actor2.pth` and `ppo_critic2.pth`:
#
# [back to top](#HDDLGym-Tutorial)

# %%
# Run the rollout with the specified model
# Replace '2' with the desired model number
# !python3 run_hddl_policy.py --Model 2
# Out:
# 2140.00s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Namespace(K_epochs=10, Loadmodel=False, Max_train_steps=50000000.0, Model=2, T_horizon=2048, activation='tanh', adv_normalization=False, batch_size=64, clip_rate=0.2, debug=False, domain='/home/rumon/dev/HDDLGym_dev/HDDL_files/Overcooked_specialization/overcooked_short_domain.hddl', dvc=device(type='cpu'), entropy_coef=0.01, entropy_coef_decay=0.99, epsilon=1.0, eval_interval=1000.0, gamma=0.99, l2_reg=0, lambd=0.95, lr=0.0001, max_episode=50, max_step=25, net_width=64, planner_time_limit=5, problem='/home/rumon/dev/HDDLGym_dev/HDDL_files/Overcooked_specialization/overcooked_short_prob2.hddl', render=False, save_interval=1000.0, seed=209, use_central_planner=False, write=False)
# /home/rumon/dev/HDDLGym_dev/learning_methods.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.critic.load_state_dict(torch.load(str(script_dir / "model/ppo_critic{}.pth").format(episode)))
# /home/rumon/dev/HDDLGym_dev/learning_methods.py:415: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.actor.load_state_dict(torch.load(str(script_dir / "model/ppo_actor{}.pth").format(episode)))
# start evaluating policy ...
# action_dict {'chef1': 'none chef1', 'chef2': 'a-interact chef2 onion-pile empty onion onion onion'}
# action_dict {'chef1': 'none chef1', 'chef2': 'a-interact chef2 pot1 onion empty empty onion-1'}
# action_dict {'chef1': 'none chef1', 'chef2': 'a-interact chef2 pot1 empty empty onion-1 cooking-soup-1-onion'}
# action_dict {'chef1': 'a-interact chef1 bowl-pile empty bowl bowl bowl', 'chef2': 'none chef2'}
# action_dict {'chef1': 'wait chef1 pot1 cooking-soup-1-onion-stage3 cooking-soup-1-onion-stage4', 'chef2': 'none chef2'}
# action_dict {'chef1': 'none chef1', 'chef2': 'none chef2'}
# action_dict {'chef1': 'a-interact chef1 pot1 bowl soup-1-onion soup-1-onion empty', 'chef2': 'none chef2'}
# action_dict {'chef1': 'a-interact chef1 delivery soup-1-onion empty empty soup-1-onion', 'chef2': 'none chef2'}
# Evaluation turn 0 completed ['make-soup soup-1-onion delivery'] after 8 steps, getting score of 84
#
# Hierarchies Record for turn  0
# [['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'add-ingredient pot1 onion onion-1', 'm-add-ingredient-1-onion pot1 onion onion-pile onion-1 empty', 'none chef1'], ['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'add-ingredient pot1 onion onion-1', 'm-add-ingredient-1-onion pot1 onion onion-pile onion-1 empty', 't-interact chef2 onion-pile onion onion', 'm-interact-direct chef2 onion-pile empty onion onion onion', 'a-interact chef2 onion-pile empty onion onion onion']]
# --
# {'chef1': 'none chef1', 'chef2': 'a-interact chef2 onion-pile empty onion onion onion'}
# [['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'add-ingredient pot1 onion onion-1', 'm-add-ingredient-1-onion pot1 onion onion-pile onion-1 empty', 'none chef1'], ['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'add-ingredient pot1 onion onion-1', 'm-add-ingredient-1-onion pot1 onion onion-pile onion-1 empty', 't-interact chef2 pot1 empty onion-1', 'm-interact-direct chef2 pot1 onion empty empty onion-1', 'a-interact chef2 pot1 onion empty empty onion-1']]
# --
# {'chef1': 'none chef1', 'chef2': 'a-interact chef2 pot1 onion empty empty onion-1'}
# [['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'cook pot1 onion-1 cooking-soup-1-onion', 'm-cook pot1 onion-1 cooking-soup-1-onion chef1 empty', 'none chef1'], ['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'cook pot1 onion-1 cooking-soup-1-onion', 'm-cook pot1 onion-1 cooking-soup-1-onion chef2 empty', 'a-interact chef2 pot1 empty empty onion-1 cooking-soup-1-onion']]
# --
# {'chef1': 'none chef1', 'chef2': 'a-interact chef2 pot1 empty empty onion-1 cooking-soup-1-onion'}
# [['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'deliver soup-1-onion delivery', 'm-deliver pot1 delivery bowl-pile soup-1-onion bowl empty', 't-interact chef1 bowl-pile bowl bowl', 'm-interact-direct chef1 bowl-pile empty bowl bowl bowl', 'a-interact chef1 bowl-pile empty bowl bowl bowl'], ['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'deliver soup-1-onion delivery', 'm-deliver pot1 delivery bowl-pile soup-1-onion bowl empty', 'none chef2']]
# --
# {'chef1': 'a-interact chef1 bowl-pile empty bowl bowl bowl', 'chef2': 'none chef2'}
# [['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'deliver soup-1-onion delivery', 'm-deliver pot1 delivery bowl-pile soup-1-onion bowl empty', 't-wait-cooking chef1 pot1 soup-1-onion', 'm-still-wait-cooking chef1 pot1 soup-1-onion cooking-soup-1-onion-stage3 cooking-soup-1-onion-stage4', 'wait chef1 pot1 cooking-soup-1-onion-stage3 cooking-soup-1-onion-stage4'], ['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'deliver soup-1-onion delivery', 'm-deliver pot1 delivery bowl-pile soup-1-onion bowl empty', 'none chef2']]
# --
# {'chef1': 'wait chef1 pot1 cooking-soup-1-onion-stage3 cooking-soup-1-onion-stage4', 'chef2': 'none chef2'}
# [['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'deliver soup-1-onion delivery', 'm-deliver pot1 delivery bowl-pile soup-1-onion bowl empty', 't-wait-cooking chef1 pot1 soup-1-onion', 'm-still-wait-cooking chef1 pot1 soup-1-onion cooking-soup-1-onion-stage3 cooking-soup-1-onion-stage4', 'none chef1'], ['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'deliver soup-1-onion delivery', 'm-deliver pot1 delivery bowl-pile soup-1-onion bowl empty', 'none chef2']]
# --
# {'chef1': 'none chef1', 'chef2': 'none chef2'}
# [['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'deliver soup-1-onion delivery', 'm-deliver pot1 delivery bowl-pile soup-1-onion bowl empty', 't-interact chef1 pot1 soup-1-onion empty', 'm-interact-direct chef1 pot1 bowl soup-1-onion soup-1-onion empty', 'a-interact chef1 pot1 bowl soup-1-onion soup-1-onion empty'], ['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'deliver soup-1-onion delivery', 'm-deliver pot1 delivery bowl-pile soup-1-onion bowl empty', 'none chef2']]
# --
# {'chef1': 'a-interact chef1 pot1 bowl soup-1-onion soup-1-onion empty', 'chef2': 'none chef2'}
# [['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'deliver soup-1-onion delivery', 'm-deliver pot1 delivery bowl-pile soup-1-onion bowl empty', 't-interact chef1 delivery empty soup-1-onion', 'm-interact-direct chef1 delivery soup-1-onion empty empty soup-1-onion', 'a-interact chef1 delivery soup-1-onion empty empty soup-1-onion'], ['make-soup soup-1-onion delivery', 'm-make-soup soup-1-onion pot1 delivery onion onion-1 cooking-soup-1-onion', 'deliver soup-1-onion delivery', 'm-deliver pot1 delivery bowl-pile soup-1-onion bowl empty', 'none chef2']]
# --
# {'chef1': 'a-interact chef1 delivery soup-1-onion empty empty soup-1-onion', 'chef2': 'none chef2'}
# Episode reward of evaluating episode 0 is 84
# Evaluation Score for /home/rumon/dev/HDDLGym_dev/HDDL_files/Overcooked_specialization/overcooked_short_prob2.hddl: 84

# %% [markdown]
# # 5.2: Launch the Local Server
# The generated data will be dumped into `website/data.json`. To visualize the data, navigate to the website folder and start a local server:

# %%
# Launch the local server on port 8000
# !python3 -m http.server 8000 --directory website
# Out:
# 2123.23s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Serving HTTP on 0.0.0.0 port 8000 (http://0.0.0.0:8000/) ...
# 127.0.0.1 - - [04/Feb/2025 14:00:44] "GET / HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Feb/2025 14:00:44] "GET /styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Feb/2025 14:00:44] "GET /script.js HTTP/1.1" 304 -
# 127.0.0.1 - - [04/Feb/2025 14:00:44] "GET /data.json HTTP/1.1" 200 -
# ^C
#
# Keyboard interrupt received, exiting.

# %% [markdown]
# # 6 [Extra]
# # Overcooked Policy Visualization Tutorial
#
# This section will guide you through the process of visualizing the Overcooked policy using Docker and Docker Compose. This has been tested on **Ubuntu 20.04**.
#
# **Prerequisites:**
# - Docker and Docker Compose must be installed on your system.
#
#
# #### Setting Up the Environment
#
# **Step 1: Navigate to the Project Directory**
#
# Open your terminal and navigate to the `overcooked_demo` directory:
#
# ```bash
# cd ../overcooked/src/overcooked_demo
# ```
#
# **Step 2: Create the `.env` File**
#
# Create a `.env` file and add the following environment variables:
#
# ```bash
# GITHUB_TOKEN=<YOUR-GITHUB-TOKEN>
# REPO_URL=<GITHUB-URL-OF-THIS-REPO>
# FLASK_SECRET_KEY=<FLASK-SECRET-KEY>
# ```
#
# Example:
#
# ```bash
# GITHUB_TOKEN=ghp_example1234567890
# REPO_URL=github.com/HDDLGym/HDDLGym.git
# FLASK_SECRET_KEY=myflasksecretkey123
# ```
#
#
# #### Building and Running the Docker Containers
#
# **Step 3: Navigate to the Server Directory**
#
# ```bash
# cd ../overcooked_demo/server
# ```
#
# **Step 4: Build the Docker Image**
#
# Use the following command to build the Docker image:
#
# ```bash
# sudo docker compose build
# ```
#
# > ⚠️ **Note:** The build process may take over **1300 seconds** (~20 minutes), depending on your system.
#
# **Step 5: Start the Docker Containers**
#
# After the build is complete, start the containers:
#
# ```bash
# sudo docker compose up
# ```
#
#
# #### Visualizing the Overcooked Policy
#
# Once the container is up and running:
#
# 1. Open your web browser.
# 2. Navigate to: [http://localhost/experiment](http://localhost/experiment)
#
# You should now be able to view the **rollout/2D visualization** of the Overcooked policy.
#
#
# #### Troubleshooting
#
# - **Docker Build Fails:** Ensure Docker and Docker Compose are properly installed and updated.
# - **Cannot Access the Visualization:** Confirm that the Docker container is running without errors and the `.env` file is correctly configured.
#
# [back to top](#HDDLGym-Tutorial)
